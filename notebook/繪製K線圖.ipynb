# %%
# basic
import numpy as np
import pandas as pd

# get data
import pandas_datareader as pdr

# visual
import matplotlib.pyplot as plt
import mpl_finance as mpf
# %matplotlib inline
import seaborn as sns

#time
import datetime as datetime

#talib
import talib

#https://nicowu.pixnet.net/blog/post/69410706 說明talib安裝

# %%
str1=

# %%
start = datetime.datetime(2020,1,1)
df_2330 = pdr.DataReader('00738U.TW', 'yahoo', start=start)

# %%
df_2330.index = df_2330.index.format(formatter=lambda x: x.strftime('%Y-%m-%d')) 

fig = plt.figure(figsize=(24, 8))

ax = fig.add_subplot(1, 1, 1)
ax.set_xticks(range(0, len(df_2330.index), 30))
ax.set_xticklabels(df_2330.index[::30])
mpf.candlestick2_ochl(ax, df_2330['Open'], df_2330['Close'], df_2330['High'],
                      df_2330['Low'], width=0.6, colorup='r', colordown='g', alpha=0.75)
# Out:
# (<matplotlib.collections.LineCollection at 0x1d378fabc10>,
#  <matplotlib.collections.PolyCollection at 0x1d37b2d7490>)

# %%
sma_5 = talib.SMA(np.array(df_2330['Close']), 5)
sma_10 = talib.SMA(np.array(df_2330['Close']), 10)
sma_20 = talib.SMA(np.array(df_2330['Close']), 20)
sma_60 = talib.SMA(np.array(df_2330['Close']), 60)

fig = plt.figure(figsize=(24, 8))
ax = fig.add_subplot(1, 1, 1)
ax.set_xticks(range(0, len(df_2330.index), 30))
ax.set_xticklabels(df_2330.index[::30])
mpf.candlestick2_ochl(ax, df_2330['Open'], df_2330['Close'], df_2330['High'],
                      df_2330['Low'], width=0.6, colorup='r', colordown='g', alpha=0.75)
plt.rcParams['font.sans-serif']=['Microsoft JhengHei'] 
ax.plot(sma_5, label='5日均線',alpha=0.9)
ax.plot(sma_10, label='10日均線',alpha=0.9)
ax.plot(sma_20, label='20日均線',alpha=0.3)
ax.plot(sma_60, label='60日均線',alpha=0.3)
ax.legend()

# %%
sma_5 = talib.SMA(np.array(df_2330['Close']), 5)
sma_10 = talib.SMA(np.array(df_2330['Close']), 10)

fig = plt.figure(figsize=(24, 15))
ax = fig.add_axes([0,0.2,1,0.5])
ax2 = fig.add_axes([0,0,1,0.2])

ax.set_xticks(range(0, len(df_2330.index), 30))
ax.set_xticklabels(df_2330.index[::30])
mpf.candlestick2_ochl(ax, df_2330['Open'], df_2330['Close'], df_2330['High'],
                      df_2330['Low'], width=0.6, colorup='r', colordown='g', alpha=0.75)
plt.rcParams['font.sans-serif']=['Microsoft JhengHei'] 
ax.plot(sma_5, label='5日均線')
ax.plot(sma_10, label='10日均線')

mpf.volume_overlay(ax2, df_2330['Open'], df_2330['Close'], df_2330['Volume'], colorup='r', colordown='g', width=0.5, alpha=0.8)
ax2.set_xticks(range(0, len(df_2330.index), 30))
ax2.set_xticklabels(df_2330.index[::30])

ax.legend()

# %%
sma_5 = talib.SMA(np.array(df_2330['Close']), 5)
sma_10 = talib.SMA(np.array(df_2330['Close']), 10)
df_2330['k'], df_2330['d'] = talib.STOCH(df_2330['High'], df_2330['Low'], df_2330['Close'])
df_2330['k'].fillna(value=0, inplace=True)
df_2330['d'].fillna(value=0, inplace=True)

fig = plt.figure(figsize=(24, 20))
ax = fig.add_axes([0,0.3,1,0.4])
ax2 = fig.add_axes([0,0.2,1,0.1])
ax3 = fig.add_axes([0,0,1,0.2])

ax.set_xticks(range(0, len(df_2330.index), 30))
ax.set_xticklabels(df_2330.index[::30])
mpf.candlestick2_ochl(ax, df_2330['Open'], df_2330['Close'], df_2330['High'],
                      df_2330['Low'], width=0.6, colorup='r', colordown='g', alpha=0.75)
plt.rcParams['font.sans-serif']=['Microsoft JhengHei'] 
ax.plot(sma_5, label='5日均線')
ax.plot(sma_10, label='10日均線')

ax2.plot(df_2330['k'], label='K值')
ax2.plot(df_2330['d'], label='D值')
ax2.set_xticks(range(0, len(df_2330.index), 30))
ax2.set_xticklabels(df_2330.index[::30])

mpf.volume_overlay(ax3, df_2330['Open'], df_2330['Close'], df_2330['Volume'], colorup='r', colordown='g', width=0.5, alpha=0.8)
ax3.set_xticks(range(0, len(df_2330.index), 30))
ax3.set_xticklabels(df_2330.index[::30])

ax.legend();
ax2.legend();

# %%
# basic
import numpy as np
import pandas as pd

# get data
import pandas_datareader as pdr

# visual
import matplotlib.pyplot as plt
import mpl_finance as mpf
# %matplotlib inline
import seaborn as sns

# time
import datetime as datetime

# talib  TA-Lib: a wrapper for the TA-LIB Technical Analysis Library.
# https://www.lfd.uci.edu/~gohlke/pythonlibs/#ta-lib
# http://mrjbq7.github.io/ta-lib/doc_index.html
# https://medium.com/ai%E8%82%A1%E4%BB%94/%E7%94%A8-python-%E5%BF%AB%E9%80%9F%E8%A8%88%E7%AE%97-158-%E7%A8%AE%E6%8A%80%E8%A1%93%E6%8C%87%E6%A8%99-26f9579b8f3a
import talib
all_ta_label = talib.get_functions()
#all_ta_label

# %%
start = datetime.datetime(2022,1,1)
df_00738U = pdr.DataReader('00738U.TW', 'yahoo', start=start)  # 期元大道瓊白銀(00738U.TW)
#df_00738U
# Out:
#                  High        Low       Open      Close   Volume  Adj Close
# Date
# 2022-01-03  23.650000  23.500000  23.590000  23.500000   900000  23.500000
# 2022-01-04  23.389999  23.090000  23.309999  23.180000   444000  23.180000
# 2022-01-05  23.389999  23.309999  23.379999  23.330000   345000  23.330000
# 2022-01-06  23.190001  22.959999  23.190001  23.020000   869086  23.020000
# 2022-01-07  22.540001  22.469999  22.540001  22.530001  1151112  22.530001
# ...               ...        ...        ...        ...      ...        ...
# 2022-05-20  22.350000  22.180000  22.240000  22.309999   906000  22.309999
# 2022-05-23  22.320000  22.200001  22.299999  22.280001   629050  22.280001
# 2022-05-24  22.139999  22.020000  22.129999  22.059999   875000  22.059999
# 2022-05-25  22.440001  22.350000  22.420000  22.400000   718000  22.400000
# 2022-05-26  22.299999  22.129999  22.299999  22.129999   399050  22.129999
#
# [93 rows x 6 columns]

# %%
df_00738U = df_00738U.drop(columns="Adj Close")
import mplfinance as mpf
mpf.plot(df_00738U,type='candle',mav=(5,10,20,60))

# %%
start = datetime.datetime(2022,1,1)
df_SI_F = pdr.DataReader('SI=F', 'yahoo', start=start)  # 期元大道瓊白銀(00738U.TW)
df_SI_F = df_SI_F.drop(columns="Adj Close")
import mplfinance as mpf
mpf.plot(df_SI_F,type='candle',mav=(5,10,20,60))

# %%
df_00738U.index
# Out:
# DatetimeIndex(['2022-01-03', '2022-01-04', '2022-01-05', '2022-01-06',
#                '2022-01-07', '2022-01-10', '2022-01-11', '2022-01-12',
#                '2022-01-13', '2022-01-14', '2022-01-17', '2022-01-18',
#                '2022-01-19', '2022-01-20', '2022-01-21', '2022-01-24',
#                '2022-01-25', '2022-01-26', '2022-02-07', '2022-02-08',
#                '2022-02-09', '2022-02-10', '2022-02-11', '2022-02-14',
#                '2022-02-15', '2022-02-16', '2022-02-17', '2022-02-18',
#                '2022-02-21', '2022-02-22', '2022-02-23', '2022-02-24',
#                '2022-02-25', '2022-03-01', '2022-03-02', '2022-03-03',
#                '2022-03-04', '2022-03-07', '2022-03-08', '2022-03-09',
#                '2022-03-10', '2022-03-11', '2022-03-14', '2022-03-15',
#                '2022-03-16', '2022-03-17', '2022-03-18', '2022-03-21',
#                '2022-03-22', '2022-03-23', '2022-03-24', '2022-03-25',
# ...
